# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/aoml-m-2-test-feb-2025/sample_submission.csv
# /kaggle/input/aoml-m-2-test-feb-2025/train.csv
# /kaggle/input/aoml-m-2-test-feb-2025/test.csv

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd

train_df_dir = "/kaggle/input/aoml-m-2-test-feb-2025/train.csv"
test_df_dir = "/kaggle/input/aoml-m-2-test-feb-2025/test.csv"

# %%
train_df = pd.read_csv(train_df_dir)
test_df = pd.read_csv(test_df_dir)

test_uid = test_df["uid"]

train_df.drop("uid", axis=1, inplace=True)
test_df.drop("uid", axis=1, inplace=True)

day_map = {
    "Friday": 0,
    "Saturday": 1,
}

train_df["day"] = train_df["day"].map(day_map)
test_df["day"] = test_df["day"].map(day_map)

train_df.drop("minute", axis=1, inplace=True)
test_df.drop("minute", axis=1, inplace=True)

print(train_df.isna().sum())
# Out:
# day                              5479
# hour                             5613
# C_motion                         5517
# feed_water_motion                5597
# faucet_hole                      5566
# vapour_pressure                  5479
# vapour_enthalpy                  5437
# vapour_pressure_at_division      5477
# vapour_motion                    5477
# feed_water_enth                  5496
# vapour_temperature               5517
# output_electricity_generation       0
# dtype: int64

# %%
from sklearn.neighbors import KNeighborsRegressor


def KNN_Imputer(df):
    for i in df.columns:
        if df[i].isna().sum() == 0:
            continue

        temp_df = df.copy()
        for x in df.columns:
            if x == i:
                continue
            temp_df[x].fillna(value=temp_df[x].mean(), inplace=True)

        col = i
        other_cols = [x for x in df.columns if x != col]
        X = temp_df[other_cols][df[col].notna()]
        y = temp_df[col][df[col].notna()]

        neigh = KNeighborsRegressor(n_neighbors=3)
        neigh.fit(np.array(X), np.array(y))

        print(f"Imputing {i}")
        for i, j in enumerate(df[col].isnull()):
            if j == True:
                df[col].iloc[i] = neigh.predict(temp_df[other_cols].iloc[i : i + 1, :])[
                    0
                ]
    return df


train_df = KNN_Imputer(train_df)
test_df = KNN_Imputer(test_df)

print(train_df.isna().sum())
# Out:
# Imputing day
# Imputing hour
# Imputing C_motion
# Imputing feed_water_motion
# Imputing faucet_hole
# Imputing vapour_pressure
# Imputing vapour_enthalpy
# Imputing vapour_pressure_at_division
# Imputing vapour_motion
# Imputing feed_water_enth
# Imputing vapour_temperature
# Imputing day
# Imputing hour
# Imputing C_motion
# Imputing feed_water_motion
# Imputing faucet_hole
# Imputing vapour_pressure
# Imputing vapour_enthalpy
# Imputing vapour_pressure_at_division
# Imputing vapour_motion
# Imputing feed_water_enth
# Imputing vapour_temperature
# day                              0
# hour                             0
# C_motion                         0
# feed_water_motion                0
# faucet_hole                      0
# vapour_pressure                  0
# vapour_enthalpy                  0
# vapour_pressure_at_division      0
# vapour_motion                    0
# feed_water_enth                  0
# vapour_temperature               0
# output_electricity_generation    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X = train_df.drop("output_electricity_generation", axis=1)
y = train_df["output_electricity_generation"]

X["vapour_pressure_per_temp"] = X["vapour_pressure"] / X["vapour_temperature"]
test_df["vapour_pressure_per_temp"] = (
    test_df["vapour_pressure"] / test_df["vapour_temperature"]
)

X["vapour_enthalpy_per_temp"] = X["vapour_enthalpy"] / X["vapour_temperature"]
test_df["vapour_enthalpy_per_temp"] = (
    test_df["vapour_enthalpy"] / test_df["vapour_temperature"]
)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train["hour_sin"] = np.sin(2 * np.pi * X_train["hour"] / 23.0)
X_train["hour_cos"] = np.cos(2 * np.pi * X_train["hour"] / 23.0)

X_test["hour_sin"] = np.sin(2 * np.pi * X_test["hour"] / 23.0)
X_test["hour_cos"] = np.cos(2 * np.pi * X_test["hour"] / 23.0)

test_df["hour_sin"] = np.sin(2 * np.pi * test_df["hour"] / 23.0)
test_df["hour_cos"] = np.cos(2 * np.pi * test_df["hour"] / 23.0)

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import mean_squared_error


def objective(trial):
    param = {
        "objective": "regression",
        "metric": "rmse",
        "verbosity": -1,
        "boosting_type": "gbdt",
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-8, 10.0, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-8, 10.0, log=True),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
    }

    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

    model = lgb.train(param, lgb_train, valid_sets=[lgb_train, lgb_eval])

    y_pred = model.predict(X_test, num_iteration=model.best_iteration)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    return rmse


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100)

lgb_params = study.best_params
lgb_params["objective"] = "regression"
lgb_params["metric"] = "rmse"
lgb_params["verbosity"] = -1
lgb_params["boosting_type"] = "gbdt"

lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

lgb_model = lgb.train(lgb_params, lgb_train, valid_sets=[lgb_train, lgb_eval])

lgb_pred = lgb_model.predict(X_test, num_iteration=lgb_model.best_iteration)
lgb_rmse = np.sqrt(mean_squared_error(y_test, lgb_pred))
print(f"LightGBM RMSE: {lgb_rmse}\n")
# Out:
# [I 2025-03-09 11:45:33,100] A new study created in memory with name: no-name-709cefa1-b656-4a4e-9c1a-661a69069b2d
# [I 2025-03-09 11:45:36,103] Trial 0 finished with value: 1.0285551031208844 and parameters: {'lambda_l1': 0.00012717141357882817, 'lambda_l2': 1.326529126063463, 'num_leaves': 185, 'feature_fraction': 0.5063428418406376, 'bagging_fraction': 0.9339303012853281, 'bagging_freq': 4, 'min_child_samples': 26}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:37,179] Trial 1 finished with value: 1.031457135839787 and parameters: {'lambda_l1': 6.569802155602175e-06, 'lambda_l2': 0.00013782163220482733, 'num_leaves': 151, 'feature_fraction': 0.4136898037127542, 'bagging_fraction': 0.7251493480360292, 'bagging_freq': 2, 'min_child_samples': 9}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:38,637] Trial 2 finished with value: 1.2867616193811704 and parameters: {'lambda_l1': 1.1862749798386223e-06, 'lambda_l2': 0.07780438745293133, 'num_leaves': 213, 'feature_fraction': 0.47616905319249825, 'bagging_fraction': 0.9151685964137923, 'bagging_freq': 4, 'min_child_samples': 91}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:39,677] Trial 3 finished with value: 1.037316480467876 and parameters: {'lambda_l1': 0.0010084123602383088, 'lambda_l2': 1.3465408198029998, 'num_leaves': 139, 'feature_fraction': 0.8351145417830471, 'bagging_fraction': 0.7822481154647623, 'bagging_freq': 2, 'min_child_samples': 18}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:40,738] Trial 4 finished with value: 1.1173407196307164 and parameters: {'lambda_l1': 2.0229500838395973e-08, 'lambda_l2': 3.382052331407579e-07, 'num_leaves': 159, 'feature_fraction': 0.512935383995286, 'bagging_fraction': 0.6428782965162466, 'bagging_freq': 5, 'min_child_samples': 31}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:42,092] Trial 5 finished with value: 1.149419028923866 and parameters: {'lambda_l1': 2.744596240920503e-07, 'lambda_l2': 1.5970761700476914e-07, 'num_leaves': 155, 'feature_fraction': 0.9279718212854311, 'bagging_fraction': 0.9962133738392611, 'bagging_freq': 6, 'min_child_samples': 92}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:43,368] Trial 6 finished with value: 1.2603228728858362 and parameters: {'lambda_l1': 1.5148264160760672e-08, 'lambda_l2': 8.279881676340208e-08, 'num_leaves': 171, 'feature_fraction': 0.7483984467518172, 'bagging_fraction': 0.7413127846608595, 'bagging_freq': 5, 'min_child_samples': 95}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:43,787] Trial 7 finished with value: 2.0443560973738193 and parameters: {'lambda_l1': 2.220973785092177, 'lambda_l2': 0.00014069747450320776, 'num_leaves': 18, 'feature_fraction': 0.5897165607862861, 'bagging_fraction': 0.9808931612658324, 'bagging_freq': 7, 'min_child_samples': 58}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:44,302] Trial 8 finished with value: 1.5255630659879436 and parameters: {'lambda_l1': 7.8646481085251e-08, 'lambda_l2': 0.021668356140114618, 'num_leaves': 38, 'feature_fraction': 0.8953783383093795, 'bagging_fraction': 0.6256458146912148, 'bagging_freq': 1, 'min_child_samples': 55}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:44,717] Trial 9 finished with value: 2.0328957916139063 and parameters: {'lambda_l1': 1.5806317828183245, 'lambda_l2': 0.04636238788995445, 'num_leaves': 18, 'feature_fraction': 0.9244361202263582, 'bagging_fraction': 0.5771159308383491, 'bagging_freq': 3, 'min_child_samples': 32}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:45,808] Trial 10 finished with value: 1.431480296885309 and parameters: {'lambda_l1': 0.0026154479742206698, 'lambda_l2': 0.7128036443703184, 'num_leaves': 239, 'feature_fraction': 0.6398803613531616, 'bagging_fraction': 0.41365512539735044, 'bagging_freq': 4, 'min_child_samples': 69}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:46,649] Trial 11 finished with value: 1.233980499580815 and parameters: {'lambda_l1': 4.2373629323701355e-05, 'lambda_l2': 0.00011192150578163722, 'num_leaves': 87, 'feature_fraction': 0.4000079115113944, 'bagging_fraction': 0.8429865471425364, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:47,522] Trial 12 finished with value: 1.3213260509120908 and parameters: {'lambda_l1': 1.6974903583084776e-05, 'lambda_l2': 1.444042793735564e-05, 'num_leaves': 95, 'feature_fraction': 0.40368350937889697, 'bagging_fraction': 0.4862620575068877, 'bagging_freq': 1, 'min_child_samples': 30}. Best is trial 0 with value: 1.0285551031208844.
# [I 2025-03-09 11:45:48,922] Trial 13 finished with value: 0.9187080564492173 and parameters: {'lambda_l1': 0.023588562519141713, 'lambda_l2': 0.004026033867242264, 'num_leaves': 202, 'feature_fraction': 0.5396058413319221, 'bagging_fraction': 0.8524441236847412, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 13 with value: 0.9187080564492173.
# [I 2025-03-09 11:45:50,262] Trial 14 finished with value: 0.979764445916024 and parameters: {'lambda_l1': 0.024531515682343137, 'lambda_l2': 0.007046993410557711, 'num_leaves': 199, 'feature_fraction': 0.5710385272604797, 'bagging_fraction': 0.878087388229033, 'bagging_freq': 3, 'min_child_samples': 21}. Best is trial 13 with value: 0.9187080564492173.
# [I 2025-03-09 11:45:51,835] Trial 15 finished with value: 0.9162341029503567 and parameters: {'lambda_l1': 0.07164129010534731, 'lambda_l2': 0.008191966384034067, 'num_leaves': 254, 'feature_fraction': 0.7066277390028347, 'bagging_fraction': 0.8473157748177237, 'bagging_freq': 3, 'min_child_samples': 16}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:45:53,451] Trial 16 finished with value: 1.0094798321916065 and parameters: {'lambda_l1': 0.10135382473684193, 'lambda_l2': 0.0029080769327489505, 'num_leaves': 254, 'feature_fraction': 0.7081189739908872, 'bagging_fraction': 0.8220345232611219, 'bagging_freq': 3, 'min_child_samples': 44}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:45:54,939] Trial 17 finished with value: 0.9234061450372621 and parameters: {'lambda_l1': 0.09715699241690866, 'lambda_l2': 9.46716841495188e-06, 'num_leaves': 223, 'feature_fraction': 0.7831751269986589, 'bagging_fraction': 0.8054404734558137, 'bagging_freq': 5, 'min_child_samples': 12}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:45:56,114] Trial 18 finished with value: 1.1157591383476455 and parameters: {'lambda_l1': 9.706995492654316, 'lambda_l2': 0.0013535597113530167, 'num_leaves': 230, 'feature_fraction': 0.6584292293848345, 'bagging_fraction': 0.6840365536800255, 'bagging_freq': 3, 'min_child_samples': 44}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:45:57,089] Trial 19 finished with value: 1.2533280402351799 and parameters: {'lambda_l1': 0.004663845063614632, 'lambda_l2': 7.902653659493096, 'num_leaves': 109, 'feature_fraction': 0.990226507225765, 'bagging_fraction': 0.8866589054143174, 'bagging_freq': 2, 'min_child_samples': 42}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:45:58,490] Trial 20 finished with value: 1.1786410502063778 and parameters: {'lambda_l1': 0.23143992332920008, 'lambda_l2': 1.2576276930949431e-05, 'num_leaves': 198, 'feature_fraction': 0.598338779344692, 'bagging_fraction': 0.7473502249614206, 'bagging_freq': 6, 'min_child_samples': 68}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:45:59,983] Trial 21 finished with value: 0.929414037060531 and parameters: {'lambda_l1': 0.01714748791220384, 'lambda_l2': 3.14819715806644e-06, 'num_leaves': 221, 'feature_fraction': 0.7689063166221086, 'bagging_fraction': 0.7941355864682533, 'bagging_freq': 5, 'min_child_samples': 14}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:01,603] Trial 22 finished with value: 0.9184815730607981 and parameters: {'lambda_l1': 0.21503426821382438, 'lambda_l2': 0.0007191037511240998, 'num_leaves': 250, 'feature_fraction': 0.8073589218621299, 'bagging_fraction': 0.8546899098891533, 'bagging_freq': 5, 'min_child_samples': 11}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:03,219] Trial 23 finished with value: 0.9206414344941828 and parameters: {'lambda_l1': 0.4747428418428909, 'lambda_l2': 0.0009229471469578484, 'num_leaves': 254, 'feature_fraction': 0.8262045314479364, 'bagging_fraction': 0.8614253549104828, 'bagging_freq': 4, 'min_child_samples': 6}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:04,711] Trial 24 finished with value: 0.924997406764835 and parameters: {'lambda_l1': 0.018064338105503744, 'lambda_l2': 0.1464772324010905, 'num_leaves': 244, 'feature_fraction': 0.6942609406059964, 'bagging_fraction': 0.940763422900863, 'bagging_freq': 6, 'min_child_samples': 21}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:07,736] Trial 25 finished with value: 0.9436234610396504 and parameters: {'lambda_l1': 0.0012604664319235586, 'lambda_l2': 0.007546477625093642, 'num_leaves': 204, 'feature_fraction': 0.8242261206428251, 'bagging_fraction': 0.9074503469203555, 'bagging_freq': 3, 'min_child_samples': 15}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:09,216] Trial 26 finished with value: 0.9997310094103614 and parameters: {'lambda_l1': 0.8599615767969345, 'lambda_l2': 0.0006018560707651256, 'num_leaves': 188, 'feature_fraction': 0.7263103583832068, 'bagging_fraction': 0.8445792883042098, 'bagging_freq': 4, 'min_child_samples': 37}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:10,518] Trial 27 finished with value: 1.0174701376195328 and parameters: {'lambda_l1': 6.915451271541575, 'lambda_l2': 0.007949179741954398, 'num_leaves': 232, 'feature_fraction': 0.6548790667932807, 'bagging_fraction': 0.9540404744818097, 'bagging_freq': 7, 'min_child_samples': 25}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:12,182] Trial 28 finished with value: 0.9572320405318925 and parameters: {'lambda_l1': 0.048205774041550686, 'lambda_l2': 1.8578253681363365e-08, 'num_leaves': 252, 'feature_fraction': 0.878447617170384, 'bagging_fraction': 0.7722547685192191, 'bagging_freq': 3, 'min_child_samples': 11}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:13,477] Trial 29 finished with value: 1.0211688770274765 and parameters: {'lambda_l1': 0.00035186747627050335, 'lambda_l2': 0.279282973854232, 'num_leaves': 186, 'feature_fraction': 0.532177425105519, 'bagging_fraction': 0.6948648545862428, 'bagging_freq': 4, 'min_child_samples': 25}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:14,759] Trial 30 finished with value: 1.0044689501253485 and parameters: {'lambda_l1': 0.007262494827598487, 'lambda_l2': 3.7434341467949634e-05, 'num_leaves': 170, 'feature_fraction': 0.7988615319982504, 'bagging_fraction': 0.944563171088517, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:16,430] Trial 31 finished with value: 0.9694897111678048 and parameters: {'lambda_l1': 0.33447625492680144, 'lambda_l2': 0.0006853730404860768, 'num_leaves': 251, 'feature_fraction': 0.8602959531185845, 'bagging_fraction': 0.8713259107764493, 'bagging_freq': 4, 'min_child_samples': 5}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:17,872] Trial 32 finished with value: 0.9873017049889359 and parameters: {'lambda_l1': 0.5309733269882013, 'lambda_l2': 0.0017521667054644712, 'num_leaves': 256, 'feature_fraction': 0.460974185420545, 'bagging_fraction': 0.8495400046508369, 'bagging_freq': 4, 'min_child_samples': 18}. Best is trial 15 with value: 0.9162341029503567.
# [I 2025-03-09 11:46:19,531] Trial 33 finished with value: 0.9097970970548412 and parameters: {'lambda_l1': 0.13131244654470178, 'lambda_l2': 0.00025482713030995256, 'num_leaves': 229, 'feature_fraction': 0.8122660858683551, 'bagging_fraction': 0.8989820751749205, 'bagging_freq': 3, 'min_child_samples': 11}. Best is trial 33 with value: 0.9097970970548412.
# [I 2025-03-09 11:46:21,021] Trial 34 finished with value: 0.9251555277668223 and parameters: {'lambda_l1': 0.00018336822241713343, 'lambda_l2': 0.00012227507957342777, 'num_leaves': 212, 'feature_fraction': 0.7470480359857687, 'bagging_fraction': 0.9145482822558857, 'bagging_freq': 2, 'min_child_samples': 12}. Best is trial 33 with value: 0.9097970970548412.
# [I 2025-03-09 11:46:22,552] Trial 35 finished with value: 0.9433250337406852 and parameters: {'lambda_l1': 0.11078707234401038, 'lambda_l2': 0.017212117229545118, 'num_leaves': 232, 'feature_fraction': 0.7058320792787389, 'bagging_fraction': 0.82538803780919, 'bagging_freq': 3, 'min_child_samples': 20}. Best is trial 33 with value: 0.9097970970548412.
# [I 2025-03-09 11:46:23,533] Trial 36 finished with value: 1.183313105290382 and parameters: {'lambda_l1': 2.468656749447148, 'lambda_l2': 0.00034133505809973727, 'num_leaves': 132, 'feature_fraction': 0.45004371762192075, 'bagging_fraction': 0.7697824024432202, 'bagging_freq': 2, 'min_child_samples': 28}. Best is trial 33 with value: 0.9097970970548412.
# [I 2025-03-09 11:46:25,141] Trial 37 finished with value: 1.108630427960929 and parameters: {'lambda_l1': 0.0007540020451143564, 'lambda_l2': 2.0060227133833756e-06, 'num_leaves': 221, 'feature_fraction': 0.7984652825642906, 'bagging_fraction': 0.8988727281744453, 'bagging_freq': 3, 'min_child_samples': 81}. Best is trial 33 with value: 0.9097970970548412.
# [I 2025-03-09 11:46:26,495] Trial 38 finished with value: 1.0892401264370952 and parameters: {'lambda_l1': 0.007635343445405555, 'lambda_l2': 0.0028376502481512605, 'num_leaves': 170, 'feature_fraction': 0.5520887687871199, 'bagging_fraction': 0.9777483442140242, 'bagging_freq': 2, 'min_child_samples': 36}. Best is trial 33 with value: 0.9097970970548412.
# [I 2025-03-09 11:46:27,949] Trial 39 finished with value: 0.9711579443441656 and parameters: {'lambda_l1': 0.04054076121945806, 'lambda_l2': 0.04774857701901236, 'num_leaves': 209, 'feature_fraction': 0.8413988457156095, 'bagging_fraction': 0.7302270094764676, 'bagging_freq': 6, 'min_child_samples': 16}. Best is trial 33 with value: 0.9097970970548412.
# [I 2025-03-09 11:46:29,340] Trial 40 finished with value: 0.9130822168970483 and parameters: {'lambda_l1': 0.1459111551670577, 'lambda_l2': 0.00022031519309341738, 'num_leaves': 240, 'feature_fraction': 0.49743092227006536, 'bagging_fraction': 0.6598654651859908, 'bagging_freq': 1, 'min_child_samples': 10}. Best is trial 33 with value: 0.9097970970548412.
# [I 2025-03-09 11:46:30,819] Trial 41 finished with value: 0.8989323134930314 and parameters: {'lambda_l1': 0.19393168893332444, 'lambda_l2': 5.353880149729641e-05, 'num_leaves': 238, 'feature_fraction': 0.5069113972013126, 'bagging_fraction': 0.6459427679180128, 'bagging_freq': 1, 'min_child_samples': 10}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:32,099] Trial 42 finished with value: 0.9560698336920437 and parameters: {'lambda_l1': 0.16538757600276346, 'lambda_l2': 4.783384998166309e-05, 'num_leaves': 240, 'feature_fraction': 0.46238554081846095, 'bagging_fraction': 0.597593121172758, 'bagging_freq': 1, 'min_child_samples': 11}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:33,361] Trial 43 finished with value: 1.0524571991049065 and parameters: {'lambda_l1': 1.7595162586326071e-06, 'lambda_l2': 0.0002652926708229502, 'num_leaves': 237, 'feature_fraction': 0.493534183353762, 'bagging_fraction': 0.6606811439807972, 'bagging_freq': 1, 'min_child_samples': 22}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:34,509] Trial 44 finished with value: 0.9919930025584945 and parameters: {'lambda_l1': 2.936192161506069, 'lambda_l2': 3.1630570207492226e-05, 'num_leaves': 220, 'feature_fraction': 0.6178851197399781, 'bagging_fraction': 0.5477291704411085, 'bagging_freq': 1, 'min_child_samples': 10}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:35,114] Trial 45 finished with value: 1.4283280212913816 and parameters: {'lambda_l1': 0.880017091412969, 'lambda_l2': 0.0002476778156418391, 'num_leaves': 44, 'feature_fraction': 0.5105110453182462, 'bagging_fraction': 0.6258536587093946, 'bagging_freq': 1, 'min_child_samples': 17}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:36,626] Trial 46 finished with value: 0.9761457319765856 and parameters: {'lambda_l1': 0.056357942895825394, 'lambda_l2': 5.410409197474108e-05, 'num_leaves': 243, 'feature_fraction': 0.4285626803130779, 'bagging_fraction': 0.6613721571618542, 'bagging_freq': 5, 'min_child_samples': 9}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:39,778] Trial 47 finished with value: 1.026893046489719 and parameters: {'lambda_l1': 0.0028183540723281126, 'lambda_l2': 9.606852771045787e-07, 'num_leaves': 228, 'feature_fraction': 0.6775508082865986, 'bagging_fraction': 0.5741610578440905, 'bagging_freq': 2, 'min_child_samples': 33}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:41,129] Trial 48 finished with value: 1.0503805792386725 and parameters: {'lambda_l1': 1.1445837502522112, 'lambda_l2': 0.00010510524303295139, 'num_leaves': 243, 'feature_fraction': 0.7708762821909176, 'bagging_fraction': 0.7091163585560524, 'bagging_freq': 1, 'min_child_samples': 50}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:42,523] Trial 49 finished with value: 1.0378239222359171 and parameters: {'lambda_l1': 0.25889209065607527, 'lambda_l2': 0.015167243035856308, 'num_leaves': 192, 'feature_fraction': 0.9034482671761134, 'bagging_fraction': 0.4844537107635305, 'bagging_freq': 1, 'min_child_samples': 24}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:43,303] Trial 50 finished with value: 1.2353393444625183 and parameters: {'lambda_l1': 3.0829289137931, 'lambda_l2': 7.606624775814511e-06, 'num_leaves': 63, 'feature_fraction': 0.9790980783688618, 'bagging_fraction': 0.5391874494776734, 'bagging_freq': 2, 'min_child_samples': 15}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:44,773] Trial 51 finished with value: 0.8989646811509209 and parameters: {'lambda_l1': 0.024109354468798586, 'lambda_l2': 0.0036266202374827844, 'num_leaves': 212, 'feature_fraction': 0.5372170143602114, 'bagging_fraction': 0.8159946388727124, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:46,065] Trial 52 finished with value: 1.6764547090183195 and parameters: {'lambda_l1': 0.012258844672456899, 'lambda_l2': 0.0003685947837447274, 'num_leaves': 213, 'feature_fraction': 0.4896157820493594, 'bagging_fraction': 0.6513728397030462, 'bagging_freq': 2, 'min_child_samples': 100}. Best is trial 41 with value: 0.8989323134930314.
# [I 2025-03-09 11:46:47,668] Trial 53 finished with value: 0.8698517181104317 and parameters: {'lambda_l1': 0.0695533802086092, 'lambda_l2': 0.002464007777569145, 'num_leaves': 244, 'feature_fraction': 0.5241411035545328, 'bagging_fraction': 0.8096549910138072, 'bagging_freq': 3, 'min_child_samples': 8}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:46:49,135] Trial 54 finished with value: 0.8857087816914345 and parameters: {'lambda_l1': 0.06916785175779312, 'lambda_l2': 0.0019100940285485635, 'num_leaves': 215, 'feature_fraction': 0.5714392980545215, 'bagging_fraction': 0.7549215445916324, 'bagging_freq': 3, 'min_child_samples': 8}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:46:50,446] Trial 55 finished with value: 0.92380224031031 and parameters: {'lambda_l1': 0.031709863922387706, 'lambda_l2': 0.0021660905806587306, 'num_leaves': 178, 'feature_fraction': 0.5606040239553968, 'bagging_fraction': 0.7578112081260645, 'bagging_freq': 3, 'min_child_samples': 8}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:46:51,678] Trial 56 finished with value: 1.168213657468045 and parameters: {'lambda_l1': 0.10702162818921068, 'lambda_l2': 0.0036193570325474766, 'num_leaves': 144, 'feature_fraction': 0.5226038526974749, 'bagging_fraction': 0.8140325134869199, 'bagging_freq': 3, 'min_child_samples': 63}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:46:53,089] Trial 57 finished with value: 1.2100872156028695 and parameters: {'lambda_l1': 0.5759600446251578, 'lambda_l2': 0.0011707304487169469, 'num_leaves': 216, 'feature_fraction': 0.5770699543774774, 'bagging_fraction': 0.7127926371530127, 'bagging_freq': 2, 'min_child_samples': 79}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:46:54,504] Trial 58 finished with value: 0.9162088095872162 and parameters: {'lambda_l1': 0.0032880250591156932, 'lambda_l2': 0.00015503567643298047, 'num_leaves': 227, 'feature_fraction': 0.6061190248734577, 'bagging_fraction': 0.7942503609076832, 'bagging_freq': 2, 'min_child_samples': 8}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:46:55,727] Trial 59 finished with value: 1.0717257502835433 and parameters: {'lambda_l1': 0.014576678489229734, 'lambda_l2': 0.030496345785714602, 'num_leaves': 197, 'feature_fraction': 0.4401075368912982, 'bagging_fraction': 0.6792239927432256, 'bagging_freq': 3, 'min_child_samples': 18}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:46:56,984] Trial 60 finished with value: 0.9332356028746899 and parameters: {'lambda_l1': 0.1595394529650185, 'lambda_l2': 1.727140058509264e-05, 'num_leaves': 209, 'feature_fraction': 0.4809258724328788, 'bagging_fraction': 0.7492597116289322, 'bagging_freq': 4, 'min_child_samples': 8}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:46:58,474] Trial 61 finished with value: 0.9221269067505753 and parameters: {'lambda_l1': 0.004695539223656915, 'lambda_l2': 9.167554731636454e-05, 'num_leaves': 227, 'feature_fraction': 0.597871668673174, 'bagging_fraction': 0.7958369659560578, 'bagging_freq': 2, 'min_child_samples': 7}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:46:59,830] Trial 62 finished with value: 0.951027237759157 and parameters: {'lambda_l1': 0.054228143008200315, 'lambda_l2': 0.00020226541868449422, 'num_leaves': 235, 'feature_fraction': 0.6238006927065182, 'bagging_fraction': 0.8261673587021336, 'bagging_freq': 1, 'min_child_samples': 13}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:01,093] Trial 63 finished with value: 0.9750504655166451 and parameters: {'lambda_l1': 0.0023509552170894914, 'lambda_l2': 0.005695774042690131, 'num_leaves': 160, 'feature_fraction': 0.5309252612641399, 'bagging_fraction': 0.7888477814264547, 'bagging_freq': 2, 'min_child_samples': 14}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:02,441] Trial 64 finished with value: 0.9248329431156572 and parameters: {'lambda_l1': 0.008003594525180072, 'lambda_l2': 0.0005874271907413177, 'num_leaves': 224, 'feature_fraction': 0.5027892626708266, 'bagging_fraction': 0.634536752863126, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:03,773] Trial 65 finished with value: 1.0190260893542922 and parameters: {'lambda_l1': 0.021346430129680537, 'lambda_l2': 4.5571658518001514e-06, 'num_leaves': 203, 'feature_fraction': 0.5439954405483247, 'bagging_fraction': 0.5949647301351046, 'bagging_freq': 1, 'min_child_samples': 20}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:05,277] Trial 66 finished with value: 0.9138092011311543 and parameters: {'lambda_l1': 0.0007751744551520252, 'lambda_l2': 2.5515030131581745e-05, 'num_leaves': 246, 'feature_fraction': 0.5796438992017809, 'bagging_fraction': 0.7292118524542338, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:06,767] Trial 67 finished with value: 0.9178997513863658 and parameters: {'lambda_l1': 8.192651818136516e-06, 'lambda_l2': 2.4168334110554442e-05, 'num_leaves': 246, 'feature_fraction': 0.5817209925112337, 'bagging_fraction': 0.7265944170990482, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:08,338] Trial 68 finished with value: 0.9299293897957276 and parameters: {'lambda_l1': 0.0005228556044820659, 'lambda_l2': 6.678830033538384e-05, 'num_leaves': 237, 'feature_fraction': 0.5661143377224959, 'bagging_fraction': 0.6857599796625639, 'bagging_freq': 3, 'min_child_samples': 13}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:09,290] Trial 69 finished with value: 1.1273000405959488 and parameters: {'lambda_l1': 5.385898131348268e-05, 'lambda_l2': 0.00047130897452316256, 'num_leaves': 111, 'feature_fraction': 0.5174355563893752, 'bagging_fraction': 0.7669283017506819, 'bagging_freq': 4, 'min_child_samples': 29}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:12,161] Trial 70 finished with value: 1.0052876651590537 and parameters: {'lambda_l1': 0.37114207515012637, 'lambda_l2': 0.0015332443870938307, 'num_leaves': 247, 'feature_fraction': 0.4740193551175496, 'bagging_fraction': 0.731467688865711, 'bagging_freq': 1, 'min_child_samples': 22}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:13,601] Trial 71 finished with value: 0.9172370943372226 and parameters: {'lambda_l1': 0.002442581653812772, 'lambda_l2': 0.0001763486005653284, 'num_leaves': 230, 'feature_fraction': 0.6181047185239187, 'bagging_fraction': 0.8021431602873161, 'bagging_freq': 2, 'min_child_samples': 8}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:14,956] Trial 72 finished with value: 0.888186581620141 and parameters: {'lambda_l1': 0.0011005649762362972, 'lambda_l2': 0.0009867396924306798, 'num_leaves': 221, 'feature_fraction': 0.5460986741765868, 'bagging_fraction': 0.7770216925900812, 'bagging_freq': 2, 'min_child_samples': 10}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:16,285] Trial 73 finished with value: 0.9565233903156766 and parameters: {'lambda_l1': 0.00017704551069244715, 'lambda_l2': 0.013193768218160245, 'num_leaves': 218, 'feature_fraction': 0.5342960915889173, 'bagging_fraction': 0.6703714517369364, 'bagging_freq': 3, 'min_child_samples': 13}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:17,664] Trial 74 finished with value: 0.9776042712631068 and parameters: {'lambda_l1': 0.10346717484370926, 'lambda_l2': 0.004719374162865756, 'num_leaves': 207, 'feature_fraction': 0.6469606087405246, 'bagging_fraction': 0.7053430616174942, 'bagging_freq': 2, 'min_child_samples': 18}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:17,948] Trial 75 finished with value: 3.717150809639443 and parameters: {'lambda_l1': 4.9021563570960404e-05, 'lambda_l2': 0.0009573517113385294, 'num_leaves': 4, 'feature_fraction': 0.5515083986947148, 'bagging_fraction': 0.7789216421296825, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:19,629] Trial 76 finished with value: 0.8897911052367147 and parameters: {'lambda_l1': 0.001427534442485593, 'lambda_l2': 0.0024965189997909355, 'num_leaves': 234, 'feature_fraction': 0.5049120910472459, 'bagging_fraction': 0.8313581588114904, 'bagging_freq': 4, 'min_child_samples': 11}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:20,960] Trial 77 finished with value: 0.960365888408996 and parameters: {'lambda_l1': 0.03596411321207427, 'lambda_l2': 0.010051671935783135, 'num_leaves': 192, 'feature_fraction': 0.4183644592175403, 'bagging_fraction': 0.8926919378615487, 'bagging_freq': 4, 'min_child_samples': 11}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:22,141] Trial 78 finished with value: 0.969212020420065 and parameters: {'lambda_l1': 0.0013140171288667025, 'lambda_l2': 0.0025436342565236646, 'num_leaves': 180, 'feature_fraction': 0.5095888486055228, 'bagging_fraction': 0.866913298957595, 'bagging_freq': 4, 'min_child_samples': 16}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:23,546] Trial 79 finished with value: 0.9052829134766254 and parameters: {'lambda_l1': 0.1858125284212697, 'lambda_l2': 0.0894453911765876, 'num_leaves': 256, 'feature_fraction': 0.46803017733307806, 'bagging_fraction': 0.8203872170131233, 'bagging_freq': 3, 'min_child_samples': 10}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:24,815] Trial 80 finished with value: 1.0643780798990092 and parameters: {'lambda_l1': 0.01038256641676179, 'lambda_l2': 2.6825870273331986, 'num_leaves': 256, 'feature_fraction': 0.4559107164914761, 'bagging_fraction': 0.8294157213674093, 'bagging_freq': 3, 'min_child_samples': 19}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:26,181] Trial 81 finished with value: 0.9416467032922 and parameters: {'lambda_l1': 0.07133820276064731, 'lambda_l2': 0.06007724598114183, 'num_leaves': 237, 'feature_fraction': 0.47662889927326824, 'bagging_fraction': 0.8323925964792889, 'bagging_freq': 3, 'min_child_samples': 10}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:27,470] Trial 82 finished with value: 0.9952319250179006 and parameters: {'lambda_l1': 0.16957484207146695, 'lambda_l2': 0.11614035158054736, 'num_leaves': 219, 'feature_fraction': 0.498948794742002, 'bagging_fraction': 0.8117065937370888, 'bagging_freq': 3, 'min_child_samples': 15}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:28,913] Trial 83 finished with value: 0.9418625135837565 and parameters: {'lambda_l1': 1.398702289743714, 'lambda_l2': 0.5707351338887694, 'num_leaves': 240, 'feature_fraction': 0.5169180883903832, 'bagging_fraction': 0.8729744688676903, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:30,310] Trial 84 finished with value: 0.9081499470607934 and parameters: {'lambda_l1': 0.6613218426763607, 'lambda_l2': 0.03520084527197563, 'num_leaves': 248, 'feature_fraction': 0.4393455350987382, 'bagging_fraction': 0.7735403632587312, 'bagging_freq': 4, 'min_child_samples': 7}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:31,623] Trial 85 finished with value: 0.9515824585117512 and parameters: {'lambda_l1': 4.397209317722423, 'lambda_l2': 0.18449132918430083, 'num_leaves': 251, 'feature_fraction': 0.44865753610076936, 'bagging_fraction': 0.9301002004438954, 'bagging_freq': 4, 'min_child_samples': 7}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:33,124] Trial 86 finished with value: 1.0648685227002885 and parameters: {'lambda_l1': 0.7334435180423444, 'lambda_l2': 0.029836265921393993, 'num_leaves': 232, 'feature_fraction': 0.4257991140978195, 'bagging_fraction': 0.8431157684339409, 'bagging_freq': 4, 'min_child_samples': 24}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:34,455] Trial 87 finished with value: 1.0195316807402524 and parameters: {'lambda_l1': 0.2411239384055654, 'lambda_l2': 0.3228079145771834, 'num_leaves': 213, 'feature_fraction': 0.4081306432234605, 'bagging_fraction': 0.7531792823832721, 'bagging_freq': 4, 'min_child_samples': 15}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:35,807] Trial 88 finished with value: 1.059138292463588 and parameters: {'lambda_l1': 0.3197752843086426, 'lambda_l2': 0.03287052920224233, 'num_leaves': 225, 'feature_fraction': 0.4684082710831893, 'bagging_fraction': 0.7802237273895554, 'bagging_freq': 4, 'min_child_samples': 27}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:37,158] Trial 89 finished with value: 0.9169800053785014 and parameters: {'lambda_l1': 0.03229922811112727, 'lambda_l2': 0.0810981201268138, 'num_leaves': 233, 'feature_fraction': 0.43386150499814363, 'bagging_fraction': 0.8124032845780537, 'bagging_freq': 3, 'min_child_samples': 10}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:38,709] Trial 90 finished with value: 0.9264473745512081 and parameters: {'lambda_l1': 4.304168431666803e-08, 'lambda_l2': 0.001606575274924543, 'num_leaves': 248, 'feature_fraction': 0.5534494157738066, 'bagging_fraction': 0.7621486250146863, 'bagging_freq': 5, 'min_child_samples': 7}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:39,986] Trial 91 finished with value: 0.9060205519365166 and parameters: {'lambda_l1': 0.15963160466230386, 'lambda_l2': 0.0007513811983072211, 'num_leaves': 241, 'feature_fraction': 0.49203131752377294, 'bagging_fraction': 0.7420911652046687, 'bagging_freq': 1, 'min_child_samples': 11}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:41,389] Trial 92 finished with value: 0.9387591847390916 and parameters: {'lambda_l1': 0.07100109876897757, 'lambda_l2': 0.004154706431895034, 'num_leaves': 243, 'feature_fraction': 0.4841785382325236, 'bagging_fraction': 0.7396584528224748, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:44,442] Trial 93 finished with value: 0.9716219114226448 and parameters: {'lambda_l1': 0.41328766764252484, 'lambda_l2': 0.0008646879869739452, 'num_leaves': 256, 'feature_fraction': 0.5320444788090001, 'bagging_fraction': 0.7818947194878103, 'bagging_freq': 4, 'min_child_samples': 17}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:45,771] Trial 94 finished with value: 0.9374534526093312 and parameters: {'lambda_l1': 0.022586253851842916, 'lambda_l2': 0.0003353890810668171, 'num_leaves': 222, 'feature_fraction': 0.4944134946207081, 'bagging_fraction': 0.8554845559540507, 'bagging_freq': 5, 'min_child_samples': 9}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:47,187] Trial 95 finished with value: 0.9562126633089699 and parameters: {'lambda_l1': 1.4394059869499138, 'lambda_l2': 0.009013944030901134, 'num_leaves': 250, 'feature_fraction': 0.4488549283470424, 'bagging_fraction': 0.8824441849172441, 'bagging_freq': 3, 'min_child_samples': 14}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:48,786] Trial 96 finished with value: 1.0429672831999814 and parameters: {'lambda_l1': 0.10157456212174082, 'lambda_l2': 0.0025753563580560032, 'num_leaves': 234, 'feature_fraction': 0.9508405750592271, 'bagging_fraction': 0.8002529876466794, 'bagging_freq': 1, 'min_child_samples': 50}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:50,232] Trial 97 finished with value: 0.8856149190665853 and parameters: {'lambda_l1': 9.414191440638994e-05, 'lambda_l2': 0.000458469222544145, 'num_leaves': 241, 'feature_fraction': 0.5182282651536512, 'bagging_fraction': 0.9623294388955708, 'bagging_freq': 3, 'min_child_samples': 11}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:51,863] Trial 98 finished with value: 0.9203007861921586 and parameters: {'lambda_l1': 0.00012837380227564694, 'lambda_l2': 0.0005538524711292357, 'num_leaves': 241, 'feature_fraction': 0.5254895538589639, 'bagging_fraction': 0.993031107372186, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 53 with value: 0.8698517181104317.
# [I 2025-03-09 11:47:53,377] Trial 99 finished with value: 0.9536818379053958 and parameters: {'lambda_l1': 0.0003166816058784933, 'lambda_l2': 0.0012032191687480702, 'num_leaves': 213, 'feature_fraction': 0.5447782504663546, 'bagging_fraction': 0.9596675734099558, 'bagging_freq': 4, 'min_child_samples': 22}. Best is trial 53 with value: 0.8698517181104317.
# LightGBM RMSE: 0.8698517181104317

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import RandomForestRegressor

estimators = [
    ("lgb", lgb.LGBMRegressor(**lgb_params)),
    ("rf", RandomForestRegressor(max_depth=32, random_state=1)),
]

stacker = StackingRegressor(
    estimators=estimators, final_estimator=RandomForestRegressor()
)
stacker.fit(X_train, y_train)

stacker_pred = stacker.predict(X_test)

stacker_rmse = np.sqrt(mean_squared_error(y_test, stacker_pred))

print(f"Stacker RMSE: {stacker_rmse}\n")
# Out:
# Stacker RMSE: 0.8270236914958408

# %%
stacker_pred = stacker.predict(test_df)
stacker_submission = pd.DataFrame(
    {"uid": test_uid, "output_electricity_generation": stacker_pred}
)
train = pd.read_csv(train_df_dir)
test = pd.read_csv(test_df_dir)

grp3_df = (
    train.groupby(["day", "hour", "minute"])["output_electricity_generation"]
    .mean()
    .reset_index()
)
grp3_df = grp3_df.rename(
    columns={"output_electricity_generation": "3_output_electricity_generation"}
)
train = train.merge(grp3_df, on=["day", "hour", "minute"], how="left")
test = test.merge(grp3_df, on=["day", "hour", "minute"], how="left")

stacker_submission.loc[
    test["3_output_electricity_generation"].notnull(), "output_electricity_generation"
] = test.loc[
    test["3_output_electricity_generation"].notnull(), "3_output_electricity_generation"
].values
stacker_submission.to_csv(f"submission.csv", index=False)
